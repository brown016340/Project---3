# %%
# Dependencies and Setup
import pandas as pd
import requests
import numpy as np
import io
import ipyleaflet
import json
from pathlib import Path
from pprint import pprint
from ipyleaflet import Map, Marker, LayersControl, SearchControl, FullScreenControl, WidgetControl, GeoJSON, LayerGroup
from geopy.exc import GeocoderTimedOut 
from geopy.geocoders import Nominatim 
from ipywidgets import link, FloatSlider
from branca.colormap import linear
from pandas_geojson import to_geojson
from ipywidgets import HTML, widgets

# %%
# Downloading the csv file from the GitHub repository
url = "https://raw.githubusercontent.com/brown016340/Project---3/benjamin/data/coords.csv"
download = requests.get(url).content

# Reading the downloaded content and turning it into a pandas dataframe
coords_df = pd.read_csv(io.StringIO(download.decode('utf-8')))

# Printing out the first 5 rows of the dataframe
coords_df.head()
# Out:
#        Country   Latitude   Longitude
# 0  Switzerland  46.798562    8.231974
# 1      Iceland  64.984182  -18.105901
# 2      Denmark  55.670249   10.333328
# 3       Norway  61.152939    8.787665
# 4       Canada  61.066692 -107.991707

# %%
# Downloading the csv file from the GitHub repository
url = "https://raw.githubusercontent.com/brown016340/Project---3/benjamin/data/2015.csv"
download = requests.get(url).content

# Reading the downloaded content and turning it into a pandas dataframe
happy15_df = pd.read_csv(io.StringIO(download.decode('utf-8')))

# Printing out the first 5 rows of the dataframe
happy15_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
# Join the dataframes
data_df = pd.merge(happy15_df, coords_df, on='Country', how='inner')
data_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual   Latitude   Longitude
# 0     0.29678            2.51738  46.798562    8.231974
# 1     0.43630            2.70201  64.984182  -18.105901
# 2     0.34139            2.49204  55.670249   10.333328
# 3     0.34699            2.46531  61.152939    8.787665
# 4     0.45811            2.45176  61.066692 -107.991707

# %%
# Convert to geo json
geo_json = to_geojson(df=data_df, lat='Latitude', lon='Longitude',
                      properties=['Country','Happiness Rank','Happiness Score'])
pprint(geo_json)
# Out:
# {'features': [{'geometry': {'coordinates': [8.2319736, 46.7985624],
#                             'type': 'Point'},
#                'properties': {'Country': 'Switzerland',
#                               'Happiness Rank': 1,
#                               'Happiness Score': 7.587},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-18.1059013, 64.9841821],
#                             'type': 'Point'},
#                'properties': {'Country': 'Iceland',
#                               'Happiness Rank': 2,
#                               'Happiness Score': 7.561},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [10.3333283, 55.670249],
#                             'type': 'Point'},
#                'properties': {'Country': 'Denmark',
#                               'Happiness Rank': 3,
#                               'Happiness Score': 7.527},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [8.7876653, 61.1529386],
#                             'type': 'Point'},
#                'properties': {'Country': 'Norway',
#                               'Happiness Rank': 4,
#                               'Happiness Score': 7.522},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-107.991707, 61.0666922],
#                             'type': 'Point'},
#                'properties': {'Country': 'Canada',
#                               'Happiness Rank': 5,
#                               'Happiness Score': 7.427},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [25.9209164, 63.2467777],
#                             'type': 'Point'},
#                'properties': {'Country': 'Finland',
#                               'Happiness Rank': 6,
#                               'Happiness Score': 7.406},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [5.541246849406163, 52.24764975],
#                             'type': 'Point'},
#                'properties': {'Country': 'Netherlands',
#                               'Happiness Rank': 7,
#                               'Happiness Score': 7.378},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [14.5208584, 59.6749712],
#                             'type': 'Point'},
#                'properties': {'Country': 'Sweden',
#                               'Happiness Rank': 8,
#                               'Happiness Score': 7.364},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [172.8344077, -41.5000831],
#                             'type': 'Point'},
#                'properties': {'Country': 'New Zealand',
#                               'Happiness Rank': 9,
#                               'Happiness Score': 7.286},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [134.755, -24.7761086],
#                             'type': 'Point'},
#                'properties': {'Country': 'Australia',
#                               'Happiness Rank': 10,
#                               'Happiness Score': 7.284},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [34.8594762, 30.8124247],
#                             'type': 'Point'},
#                'properties': {'Country': 'Israel',
#                               'Happiness Rank': 11,
#                               'Happiness Score': 7.278},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-84.17566257468567, 9.5364569],
#                             'type': 'Point'},
#                'properties': {'Country': 'Costa Rica',
#                               'Happiness Rank': 12,
#                               'Happiness Score': 7.226},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [14.12456, 47.59397],
#                             'type': 'Point'},
#                'properties': {'Country': 'Austria',
#                               'Happiness Rank': 13,
#                               'Happiness Score': 7.2},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-102.0077097, 23.6585116],
#                             'type': 'Point'},
#                'properties': {'Country': 'Mexico',
#                               'Happiness Rank': 14,
#                               'Happiness Score': 7.187},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-100.445882, 39.7837304],
#                             'type': 'Point'},
#                'properties': {'Country': 'United States of America',
#                               'Happiness Rank': 15,
#                               'Happiness Score': 7.119},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-53.2, -10.3333333],
#                             'type': 'Point'},
#                'properties': {'Country': 'Brazil',
#                               'Happiness Rank': 16,
#                               'Happiness Score': 6.983},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [6.1296751, 49.8158683],
#                             'type': 'Point'},
#                'properties': {'Country': 'Luxembourg',
#                               'Happiness Rank': 17,
#                               'Happiness Score': 6.946},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-7.9794599, 52.865196],
#                             'type': 'Point'},
#                'properties': {'Country': 'Ireland',
#                               'Happiness Rank': 18,
#                               'Happiness Score': 6.94},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [4.6667145, 50.6402809],
#                             'type': 'Point'},
#                'properties': {'Country': 'Belgium',
#                               'Happiness Rank': 19,
#                               'Happiness Score': 6.937},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [53.9994829, 24.0002488],
#                             'type': 'Point'},
#                'properties': {'Country': 'United Arab Emirates',
#                               'Happiness Rank': 20,
#                               'Happiness Score': 6.901},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.2765753, 54.7023545],
#                             'type': 'Point'},
#                'properties': {'Country': 'United Kingdom',
#                               'Happiness Rank': 21,
#                               'Happiness Score': 6.867},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [57.0036901, 21.0000287],
#                             'type': 'Point'},
#                'properties': {'Country': 'Oman',
#                               'Happiness Rank': 22,
#                               'Happiness Score': 6.853},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-66.1109318, 8.0018709],
#                             'type': 'Point'},
#                'properties': {'Country': 'Venezuela',
#                               'Happiness Rank': 23,
#                               'Happiness Score': 6.81},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [103.8194992, 1.357107],
#                             'type': 'Point'},
#                'properties': {'Country': 'Singapore',
#                               'Happiness Rank': 24,
#                               'Happiness Score': 6.798},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-81.1308434, 8.559559],
#                             'type': 'Point'},
#                'properties': {'Country': 'Panama',
#                               'Happiness Rank': 25,
#                               'Happiness Score': 6.786},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [10.4478313, 51.1638175],
#                             'type': 'Point'},
#                'properties': {'Country': 'Germany',
#                               'Happiness Rank': 26,
#                               'Happiness Score': 6.75},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-71.3187697, -31.7613365],
#                             'type': 'Point'},
#                'properties': {'Country': 'Chile',
#                               'Happiness Rank': 27,
#                               'Happiness Score': 6.67},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [51.2295295, 25.3336984],
#                             'type': 'Point'},
#                'properties': {'Country': 'Qatar',
#                               'Happiness Rank': 28,
#                               'Happiness Score': 6.611},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [1.8883335, 46.603354],
#                             'type': 'Point'},
#                'properties': {'Country': 'France',
#                               'Happiness Rank': 29,
#                               'Happiness Score': 6.575},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-64.9672817, -34.9964963],
#                             'type': 'Point'},
#                'properties': {'Country': 'Argentina',
#                               'Happiness Rank': 30,
#                               'Happiness Score': 6.574},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [15.3381061, 49.7439047],
#                             'type': 'Point'},
#                'properties': {'Country': 'Czech Republic',
#                               'Happiness Rank': 31,
#                               'Happiness Score': 6.505},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-56.0201525, -32.8755548],
#                             'type': 'Point'},
#                'properties': {'Country': 'Uruguay',
#                               'Happiness Rank': 32,
#                               'Happiness Score': 6.485},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-72.9088133, 4.099917],
#                             'type': 'Point'},
#                'properties': {'Country': 'Colombia',
#                               'Happiness Rank': 33,
#                               'Happiness Score': 6.477},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [100.83273, 14.8971921],
#                             'type': 'Point'},
#                'properties': {'Country': 'Thailand',
#                               'Happiness Rank': 34,
#                               'Happiness Score': 6.455},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [42.3528328, 25.6242618],
#                             'type': 'Point'},
#                'properties': {'Country': 'Saudi Arabia',
#                               'Happiness Rank': 35,
#                               'Happiness Score': 6.411},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-4.8379791, 39.3260685],
#                             'type': 'Point'},
#                'properties': {'Country': 'Spain',
#                               'Happiness Rank': 36,
#                               'Happiness Score': 6.329},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [14.4476911, 35.8885993],
#                             'type': 'Point'},
#                'properties': {'Country': 'Malta',
#                               'Happiness Rank': 37,
#                               'Happiness Score': 6.302},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [120.9820179, 23.9739374],
#                             'type': 'Point'},
#                'properties': {'Country': 'Taiwan',
#                               'Happiness Rank': 38,
#                               'Happiness Score': 6.298},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [47.4979476, 29.2733964],
#                             'type': 'Point'},
#                'properties': {'Country': 'Kuwait',
#                               'Happiness Rank': 39,
#                               'Happiness Score': 6.295},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-56.0771187, 4.1413025],
#                             'type': 'Point'},
#                'properties': {'Country': 'Suriname',
#                               'Happiness Rank': 40,
#                               'Happiness Score': 6.269},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-61.0840075, 10.7466905],
#                             'type': 'Point'},
#                'properties': {'Country': 'Trinidad and Tobago',
#                               'Happiness Rank': 41,
#                               'Happiness Score': 6.168},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-88.9140683, 13.8000382],
#                             'type': 'Point'},
#                'properties': {'Country': 'El Salvador',
#                               'Happiness Rank': 42,
#                               'Happiness Score': 6.13},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-90.345759, 15.5855545],
#                             'type': 'Point'},
#                'properties': {'Country': 'Guatemala',
#                               'Happiness Rank': 43,
#                               'Happiness Score': 6.123},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [63.9528098, 41.32373],
#                             'type': 'Point'},
#                'properties': {'Country': 'Uzbekistan',
#                               'Happiness Rank': 44,
#                               'Happiness Score': 6.003},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [19.4528646, 48.7411522],
#                             'type': 'Point'},
#                'properties': {'Country': 'Slovakia',
#                               'Happiness Rank': 45,
#                               'Happiness Score': 5.995},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [139.2394179, 36.5748441],
#                             'type': 'Point'},
#                'properties': {'Country': 'Japan',
#                               'Happiness Rank': 46,
#                               'Happiness Score': 5.987},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [127.6961188, 36.638392],
#                             'type': 'Point'},
#                'properties': {'Country': 'South Korea',
#                               'Happiness Rank': 47,
#                               'Happiness Score': 5.984},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-79.3666965, -1.3397668],
#                             'type': 'Point'},
#                'properties': {'Country': 'Ecuador',
#                               'Happiness Rank': 48,
#                               'Happiness Score': 5.975},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [50.5344606, 26.1551249],
#                             'type': 'Point'},
#                'properties': {'Country': 'Bahrain',
#                               'Happiness Rank': 49,
#                               'Happiness Score': 5.96},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [12.674297, 42.6384261],
#                             'type': 'Point'},
#                'properties': {'Country': 'Italy',
#                               'Happiness Rank': 50,
#                               'Happiness Score': 5.948},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-64.9912286, -17.0568696],
#                             'type': 'Point'},
#                'properties': {'Country': 'Bolivia',
#                               'Happiness Rank': 51,
#                               'Happiness Score': 5.89},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [28.5670941, 47.2879608],
#                             'type': 'Point'},
#                'properties': {'Country': 'Moldova',
#                               'Happiness Rank': 52,
#                               'Happiness Score': 5.889},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-58.1693445, -23.3165935],
#                             'type': 'Point'},
#                'properties': {'Country': 'Paraguay',
#                               'Happiness Rank': 53,
#                               'Happiness Score': 5.878},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [66.7780818, 48.1012954],
#                             'type': 'Point'},
#                'properties': {'Country': 'Kazakhstan',
#                               'Happiness Rank': 54,
#                               'Happiness Score': 5.855},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [14.8153333, 46.1199444],
#                             'type': 'Point'},
#                'properties': {'Country': 'Slovenia',
#                               'Happiness Rank': 55,
#                               'Happiness Score': 5.848},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [23.7499997, 55.3500003],
#                             'type': 'Point'},
#                'properties': {'Country': 'Lithuania',
#                               'Happiness Rank': 56,
#                               'Happiness Score': 5.833},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-85.2936911, 12.6090157],
#                             'type': 'Point'},
#                'properties': {'Country': 'Nicaragua',
#                               'Happiness Rank': 57,
#                               'Happiness Score': 5.828},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-75.0458515, -6.8699697],
#                             'type': 'Point'},
#                'properties': {'Country': 'Peru',
#                               'Happiness Rank': 58,
#                               'Happiness Score': 5.824},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [27.6971358, 53.4250605],
#                             'type': 'Point'},
#                'properties': {'Country': 'Belarus',
#                               'Happiness Rank': 59,
#                               'Happiness Score': 5.813},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [19.134422, 52.215933],
#                             'type': 'Point'},
#                'properties': {'Country': 'Poland',
#                               'Happiness Rank': 60,
#                               'Happiness Score': 5.791},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [102.2656823, 4.5693754],
#                             'type': 'Point'},
#                'properties': {'Country': 'Malaysia',
#                               'Happiness Rank': 61,
#                               'Happiness Score': 5.77},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [15.6575209, 45.3658443],
#                             'type': 'Point'},
#                'properties': {'Country': 'Croatia',
#                               'Happiness Rank': 62,
#                               'Happiness Score': 5.759},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [18.1236723, 26.8234472],
#                             'type': 'Point'},
#                'properties': {'Country': 'Libya',
#                               'Happiness Rank': 63,
#                               'Happiness Score': 5.754},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [97.7453061, 64.6863136],
#                             'type': 'Point'},
#                'properties': {'Country': 'Russia',
#                               'Happiness Rank': 64,
#                               'Happiness Score': 5.716},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-77.3947693, 18.1850507],
#                             'type': 'Point'},
#                'properties': {'Country': 'Jamaica',
#                               'Happiness Rank': 65,
#                               'Happiness Score': 5.709},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [33.6252379, 35.2245313],
#                             'type': 'Point'},
#                'properties': {'Country': 'Northern Cyprus',
#                               'Happiness Rank': 66,
#                               'Happiness Score': 5.695},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [33.1451285, 34.9823018],
#                             'type': 'Point'},
#                'properties': {'Country': 'Cyprus',
#                               'Happiness Rank': 67,
#                               'Happiness Score': 5.689},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [2.9999825, 28.0000272],
#                             'type': 'Point'},
#                'properties': {'Country': 'Algeria',
#                               'Happiness Rank': 68,
#                               'Happiness Score': 5.605},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [20.9021231, 42.5869578],
#                             'type': 'Point'},
#                'properties': {'Country': 'Kosovo',
#                               'Happiness Rank': 69,
#                               'Happiness Score': 5.589},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [59.3924609, 39.3763807],
#                             'type': 'Point'},
#                'properties': {'Country': 'Turkmenistan',
#                               'Happiness Rank': 70,
#                               'Happiness Score': 5.548},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [57.5703566, -20.2759451],
#                             'type': 'Point'},
#                'properties': {'Country': 'Mauritius',
#                               'Happiness Rank': 71,
#                               'Happiness Score': 5.477},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [114.1849161, 22.350627],
#                             'type': 'Point'},
#                'properties': {'Country': 'Hong Kong S.A.R.',
#                               'Happiness Rank': 72,
#                               'Happiness Score': 5.474},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [25.3319078, 58.7523778],
#                             'type': 'Point'},
#                'properties': {'Country': 'Estonia',
#                               'Happiness Rank': 73,
#                               'Happiness Score': 5.429},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [117.8902853, -2.4833826],
#                             'type': 'Point'},
#                'properties': {'Country': 'Indonesia',
#                               'Happiness Rank': 74,
#                               'Happiness Score': 5.399},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [107.9650855, 15.9266657],
#                             'type': 'Point'},
#                'properties': {'Country': 'Vietnam',
#                               'Happiness Rank': 75,
#                               'Happiness Score': 5.36},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [34.9249653, 38.9597594],
#                             'type': 'Point'},
#                'properties': {'Country': 'Turkey',
#                               'Happiness Rank': 76,
#                               'Happiness Score': 5.332},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [74.724091, 41.5089324],
#                             'type': 'Point'},
#                'properties': {'Country': 'Kyrgyzstan',
#                               'Happiness Rank': 77,
#                               'Happiness Score': 5.286},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [7.9999721, 9.6000359],
#                             'type': 'Point'},
#                'properties': {'Country': 'Nigeria',
#                               'Happiness Rank': 78,
#                               'Happiness Score': 5.268},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [90.5119273, 27.549511],
#                             'type': 'Point'},
#                'properties': {'Country': 'Bhutan',
#                               'Happiness Rank': 79,
#                               'Happiness Score': 5.253},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [47.7872508, 40.3936294],
#                             'type': 'Point'},
#                'properties': {'Country': 'Azerbaijan',
#                               'Happiness Rank': 80,
#                               'Happiness Score': 5.212},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [71.247499, 30.3308401],
#                             'type': 'Point'},
#                'properties': {'Country': 'Pakistan',
#                               'Happiness Rank': 81,
#                               'Happiness Score': 5.194},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [36.941628, 31.1667049],
#                             'type': 'Point'},
#                'properties': {'Country': 'Jordan',
#                               'Happiness Rank': 82,
#                               'Happiness Score': 5.192},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [19.5180992, 42.9868853],
#                             'type': 'Point'},
#                'properties': {'Country': 'Montenegro',
#                               'Happiness Rank': 82,
#                               'Happiness Score': 5.192},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [104.999927, 35.000074],
#                             'type': 'Point'},
#                'properties': {'Country': 'China',
#                               'Happiness Rank': 84,
#                               'Happiness Score': 5.14},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [27.5589884, -14.5189121],
#                             'type': 'Point'},
#                'properties': {'Country': 'Zambia',
#                               'Happiness Rank': 85,
#                               'Happiness Score': 5.129},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [24.6859225, 45.9852129],
#                             'type': 'Point'},
#                'properties': {'Country': 'Romania',
#                               'Happiness Rank': 86,
#                               'Happiness Score': 5.124},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [20.55144, 44.1534121],
#                             'type': 'Point'},
#                'properties': {'Country': 'Republic of Serbia',
#                               'Happiness Rank': 87,
#                               'Happiness Score': 5.123},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-8.1353519, 39.6621648],
#                             'type': 'Point'},
#                'properties': {'Country': 'Portugal',
#                               'Happiness Rank': 88,
#                               'Happiness Score': 5.102},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [24.7537645, 56.8406494],
#                             'type': 'Point'},
#                'properties': {'Country': 'Latvia',
#                               'Happiness Rank': 89,
#                               'Happiness Score': 5.098},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [122.7312101, 12.7503486],
#                             'type': 'Point'},
#                'properties': {'Country': 'Philippines',
#                               'Happiness Rank': 90,
#                               'Happiness Score': 5.073},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [46.0099127, 9.7277474],
#                             'type': 'Point'},
#                'properties': {'Country': 'Somaliland',
#                               'Happiness Rank': 91,
#                               'Happiness Score': 5.057},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-7.3362482, 31.1728205],
#                             'type': 'Point'},
#                'properties': {'Country': 'Morocco',
#                               'Happiness Rank': 92,
#                               'Happiness Score': 5.013},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [21.7168387, 41.6171214],
#                             'type': 'Point'},
#                'properties': {'Country': 'Macedonia',
#                               'Happiness Rank': 93,
#                               'Happiness Score': 5.007},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [34.9144977, -19.302233],
#                             'type': 'Point'},
#                'properties': {'Country': 'Mozambique',
#                               'Happiness Rank': 94,
#                               'Happiness Score': 4.971},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [19.9999619, 41.000028],
#                             'type': 'Point'},
#                'properties': {'Country': 'Albania',
#                               'Happiness Rank': 95,
#                               'Happiness Score': 4.959},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [17.5961467, 44.3053476],
#                             'type': 'Point'},
#                'properties': {'Country': 'Bosnia and Herzegovina',
#                               'Happiness Rank': 96,
#                               'Happiness Score': 4.949},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [28.3350193, -29.6039267],
#                             'type': 'Point'},
#                'properties': {'Country': 'Lesotho',
#                               'Happiness Rank': 97,
#                               'Happiness Score': 4.898},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.3028026, 19.0974031],
#                             'type': 'Point'},
#                'properties': {'Country': 'Dominican Republic',
#                               'Happiness Rank': 98,
#                               'Happiness Score': 4.885},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [103.378253, 20.0171109],
#                             'type': 'Point'},
#                'properties': {'Country': 'Laos',
#                               'Happiness Rank': 99,
#                               'Happiness Score': 4.876},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [103.8499736, 46.8250388],
#                             'type': 'Point'},
#                'properties': {'Country': 'Mongolia',
#                               'Happiness Rank': 100,
#                               'Happiness Score': 4.874},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [31.3991317, -26.5624806],
#                             'type': 'Point'},
#                'properties': {'Country': 'Swaziland',
#                               'Happiness Rank': 101,
#                               'Happiness Score': 4.867},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [21.9877132, 38.9953683],
#                             'type': 'Point'},
#                'properties': {'Country': 'Greece',
#                               'Happiness Rank': 102,
#                               'Happiness Score': 4.857},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [35.843409, 33.8750629],
#                             'type': 'Point'},
#                'properties': {'Country': 'Lebanon',
#                               'Happiness Rank': 103,
#                               'Happiness Score': 4.839},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [19.5060937, 47.1817585],
#                             'type': 'Point'},
#                'properties': {'Country': 'Hungary',
#                               'Happiness Rank': 104,
#                               'Happiness Score': 4.8},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-86.0755145, 15.2572432],
#                             'type': 'Point'},
#                'properties': {'Country': 'Honduras',
#                               'Happiness Rank': 105,
#                               'Happiness Score': 4.788},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [70.8156541, 38.6281733],
#                             'type': 'Point'},
#                'properties': {'Country': 'Tajikistan',
#                               'Happiness Rank': 106,
#                               'Happiness Score': 4.786},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [9.400138, 33.8439408],
#                             'type': 'Point'},
#                'properties': {'Country': 'Tunisia',
#                               'Happiness Rank': 107,
#                               'Happiness Score': 4.739},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [34.9384953773143, 31.76296362055],
#                             'type': 'Point'},
#                'properties': {'Country': 'Palestine',
#                               'Happiness Rank': 108,
#                               'Happiness Score': 4.715},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [90.2934413, 24.4769288],
#                             'type': 'Point'},
#                'properties': {'Country': 'Bangladesh',
#                               'Happiness Rank': 109,
#                               'Happiness Score': 4.694},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [54.5643516, 32.6475314],
#                             'type': 'Point'},
#                'properties': {'Country': 'Iran',
#                               'Happiness Rank': 110,
#                               'Happiness Score': 4.686},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [31.2718321, 49.4871968],
#                             'type': 'Point'},
#                'properties': {'Country': 'Ukraine',
#                               'Happiness Rank': 111,
#                               'Happiness Score': 4.681},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [44.1749775, 33.0955793],
#                             'type': 'Point'},
#                'properties': {'Country': 'Iraq',
#                               'Happiness Rank': 112,
#                               'Happiness Score': 4.677},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [24.991639, -28.8166236],
#                             'type': 'Point'},
#                'properties': {'Country': 'South Africa',
#                               'Happiness Rank': 113,
#                               'Happiness Score': 4.642},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-1.0800271, 8.0300284],
#                             'type': 'Point'},
#                'properties': {'Country': 'Ghana',
#                               'Happiness Rank': 114,
#                               'Happiness Score': 4.633},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [29.7468414, -18.4554963],
#                             'type': 'Point'},
#                'properties': {'Country': 'Zimbabwe',
#                               'Happiness Rank': 115,
#                               'Happiness Score': 4.61},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-9.3658524, 5.7499721],
#                             'type': 'Point'},
#                'properties': {'Country': 'Liberia',
#                               'Happiness Rank': 116,
#                               'Happiness Score': 4.571},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [78.6677428, 22.3511148],
#                             'type': 'Point'},
#                'properties': {'Country': 'India',
#                               'Happiness Rank': 117,
#                               'Happiness Score': 4.565},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [29.4917691, 14.5844444],
#                             'type': 'Point'},
#                'properties': {'Country': 'Sudan',
#                               'Happiness Rank': 118,
#                               'Happiness Score': 4.55},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-72.3570972, 19.1399952],
#                             'type': 'Point'},
#                'properties': {'Country': 'Haiti',
#                               'Happiness Rank': 119,
#                               'Happiness Score': 4.518},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [23.8222636, -2.9814344],
#                             'type': 'Point'},
#                'properties': {'Country': 'Democratic Republic of the Congo',
#                               'Happiness Rank': 120,
#                               'Happiness Score': 4.517},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [84.0917139, 28.1083929],
#                             'type': 'Point'},
#                'properties': {'Country': 'Nepal',
#                               'Happiness Rank': 121,
#                               'Happiness Score': 4.514},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [38.6521203, 10.2116702],
#                             'type': 'Point'},
#                'properties': {'Country': 'Ethiopia',
#                               'Happiness Rank': 122,
#                               'Happiness Score': 4.512},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-11.8400269, 8.6400349],
#                             'type': 'Point'},
#                'properties': {'Country': 'Sierra Leone',
#                               'Happiness Rank': 123,
#                               'Happiness Score': 4.507},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-9.2399263, 20.2540382],
#                             'type': 'Point'},
#                'properties': {'Country': 'Mauritania',
#                               'Happiness Rank': 124,
#                               'Happiness Score': 4.436},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [38.4313975, 1.4419683],
#                             'type': 'Point'},
#                'properties': {'Country': 'Kenya',
#                               'Happiness Rank': 125,
#                               'Happiness Score': 4.419},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [42.8453061, 11.8145966],
#                             'type': 'Point'},
#                'properties': {'Country': 'Djibouti',
#                               'Happiness Rank': 126,
#                               'Happiness Score': 4.369},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [44.6736646, 40.7696272],
#                             'type': 'Point'},
#                'properties': {'Country': 'Armenia',
#                               'Happiness Rank': 127,
#                               'Happiness Score': 4.35},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [24.5928742, -23.1681782],
#                             'type': 'Point'},
#                'properties': {'Country': 'Botswana',
#                               'Happiness Rank': 128,
#                               'Happiness Score': 4.332},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [95.9999652, 17.1750495],
#                             'type': 'Point'},
#                'properties': {'Country': 'Myanmar',
#                               'Happiness Rank': 129,
#                               'Happiness Score': 4.307},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [44.0287382, 41.6809707],
#                             'type': 'Point'},
#                'properties': {'Country': 'Georgia',
#                               'Happiness Rank': 130,
#                               'Happiness Score': 4.297},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [33.9301963, -13.2687204],
#                             'type': 'Point'},
#                'properties': {'Country': 'Malawi',
#                               'Happiness Rank': 131,
#                               'Happiness Score': 4.292},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [80.7137847, 7.5554942],
#                             'type': 'Point'},
#                'properties': {'Country': 'Sri Lanka',
#                               'Happiness Rank': 132,
#                               'Happiness Score': 4.271},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [13.1535811, 4.6125522],
#                             'type': 'Point'},
#                'properties': {'Country': 'Cameroon',
#                               'Happiness Rank': 133,
#                               'Happiness Score': 4.252},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [25.4856617, 42.6073975],
#                             'type': 'Point'},
#                'properties': {'Country': 'Bulgaria',
#                               'Happiness Rank': 134,
#                               'Happiness Score': 4.218},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [29.2675469, 26.2540493],
#                             'type': 'Point'},
#                'properties': {'Country': 'Egypt',
#                               'Happiness Rank': 135,
#                               'Happiness Score': 4.194},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [47.8915271, 16.3471243],
#                             'type': 'Point'},
#                'properties': {'Country': 'Yemen',
#                               'Happiness Rank': 136,
#                               'Happiness Score': 4.077},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [17.5691241, -11.8775768],
#                             'type': 'Point'},
#                'properties': {'Country': 'Angola',
#                               'Happiness Rank': 137,
#                               'Happiness Score': 4.033},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-2.2900239, 16.3700359],
#                             'type': 'Point'},
#                'properties': {'Country': 'Mali',
#                               'Happiness Rank': 138,
#                               'Happiness Score': 3.995},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [15.6419155, -0.7264327],
#                             'type': 'Point'},
#                'properties': {'Country': 'Republic of Congo',
#                               'Happiness Rank': 139,
#                               'Happiness Score': 3.989},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [44.2832964, -12.2045176],
#                             'type': 'Point'},
#                'properties': {'Country': 'Comoros',
#                               'Happiness Rank': 140,
#                               'Happiness Score': 3.956},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [32.2166578, 1.5333554],
#                             'type': 'Point'},
#                'properties': {'Country': 'Uganda',
#                               'Happiness Rank': 141,
#                               'Happiness Score': 3.931},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-14.4529612, 14.4750607],
#                             'type': 'Point'},
#                'properties': {'Country': 'Senegal',
#                               'Happiness Rank': 142,
#                               'Happiness Score': 3.904},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [11.6899699, -0.8999695],
#                             'type': 'Point'},
#                'properties': {'Country': 'Gabon',
#                               'Happiness Rank': 143,
#                               'Happiness Score': 3.896},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [9.3238432, 17.7356214],
#                             'type': 'Point'},
#                'properties': {'Country': 'Niger',
#                               'Happiness Rank': 144,
#                               'Happiness Score': 3.845},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [104.8144914, 12.5433216],
#                             'type': 'Point'},
#                'properties': {'Country': 'Cambodia',
#                               'Happiness Rank': 145,
#                               'Happiness Score': 3.819},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [35.7878438, -6.5247123],
#                             'type': 'Point'},
#                'properties': {'Country': 'United Republic of Tanzania',
#                               'Happiness Rank': 146,
#                               'Happiness Score': 3.781},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [46.4416422, -18.9249604],
#                             'type': 'Point'},
#                'properties': {'Country': 'Madagascar',
#                               'Happiness Rank': 147,
#                               'Happiness Score': 3.681},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [19.9981227, 7.0323598],
#                             'type': 'Point'},
#                'properties': {'Country': 'Central African Republic',
#                               'Happiness Rank': 148,
#                               'Happiness Score': 3.678},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [19.0156172, 15.6134137],
#                             'type': 'Point'},
#                'properties': {'Country': 'Chad',
#                               'Happiness Rank': 149,
#                               'Happiness Score': 3.667},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-10.7083587, 10.7226226],
#                             'type': 'Point'},
#                'properties': {'Country': 'Guinea',
#                               'Happiness Rank': 150,
#                               'Happiness Score': 3.656},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-5.5679458, 7.9897371],
#                             'type': 'Point'},
#                'properties': {'Country': 'Ivory Coast',
#                               'Happiness Rank': 151,
#                               'Happiness Score': 3.655},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-1.6880314, 12.0753083],
#                             'type': 'Point'},
#                'properties': {'Country': 'Burkina Faso',
#                               'Happiness Rank': 152,
#                               'Happiness Score': 3.587},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [66.2385139, 33.7680065],
#                             'type': 'Point'},
#                'properties': {'Country': 'Afghanistan',
#                               'Happiness Rank': 153,
#                               'Happiness Score': 3.575},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [30.0644358, -1.9646631],
#                             'type': 'Point'},
#                'properties': {'Country': 'Rwanda',
#                               'Happiness Rank': 154,
#                               'Happiness Score': 3.465},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [2.2584408, 9.5293472],
#                             'type': 'Point'},
#                'properties': {'Country': 'Benin',
#                               'Happiness Rank': 155,
#                               'Happiness Score': 3.34},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [39.0494106, 34.6401861],
#                             'type': 'Point'},
#                'properties': {'Country': 'Syria',
#                               'Happiness Rank': 156,
#                               'Happiness Score': 3.006},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [29.9324519, -3.426449],
#                             'type': 'Point'},
#                'properties': {'Country': 'Burundi',
#                               'Happiness Rank': 157,
#                               'Happiness Score': 2.905},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [1.0199765, 8.7800265],
#                             'type': 'Point'},
#                'properties': {'Country': 'Togo',
#                               'Happiness Rank': 158,
#                               'Happiness Score': 2.839},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Serializing json
json_object = json.dumps(geo_json)
 
# Writing to sample.json
with open("C:/Users/Brown/Documents/sample.geo.json", "w") as outfile:
    outfile.write(json_object)

# %%
# Function to add 'id' field to each feature
def add_id_to_features(json_data):
    for feature in json_data['features']:
        # Assuming 'Country' is unique for each feature
        country_name = feature['properties'].get('Country', 'Unknown')
        # Create a simple identifier based on the first three characters of the country name
        feature['id'] = country_name[:2].upper()

# Call the function to add 'id' field
add_id_to_features(geo_json)

# Print the modified JSON
# pprint(geo_json)

# %%
# Load the country geojson that has polygon data for each country
def load_data(url, filename, file_type):
    r = requests.get(url)
    with open(filename, 'w') as f:
        f.write(r.content.decode("utf-8"))
    with open(filename, 'r') as f:
        return file_type(f)

geo_json_data = load_data(
    'https://raw.githubusercontent.com/brown016340/Project---3/benjamin/data/countries.geojson',
    'countries.json',
     json.load)

# %%
# Add the polygon coords to the original json
admin_country_mapping = {feature['properties']['ADMIN']: feature for feature in geo_json_data['features']}

# Update the geometry in geo_json based on the mapping
for feature in geo_json['features']:
    country_name = feature['properties']['Country']
    if country_name in admin_country_mapping:
        new_geometry = admin_country_mapping[country_name]['geometry']
        feature['geometry'] = new_geometry

# %%
with open('../data/sample.geo.json') as f:
    data = json.load(f)

# %%
# Load the choropleth map
layer = ipyleaflet.Choropleth(
    geo_data= data,
    choro_data=dict(zip(data_df['Country'].str[:2].str.upper().tolist(), data_df['Happiness Score'].tolist())),
    colormap=linear.YlOrRd_04,
    border_color='black',
    style={'fillOpacity': 0.8, 'dashArray': '5, 5'},
    name= '2015'
)
m = ipyleaflet.Map(center = (0,0), zoom = 1)
m.add(layer)
# Out:
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…

# %%
control = LayersControl(position='topright')
m.add(control)
# Out:
# Map(bottom=403.0, center=[34.88593094075317, 104.0625], controls=(ZoomControl(options=['position', 'zoom_in_te…

# %%
m.add(SearchControl(
  position="topleft",
  url='https://nominatim.openstreetmap.org/search?format=json&featuretype=country&language=en&q={s}',
  zoom=4,
  # marker=marker
))

m

# %%
m.add(FullScreenControl())

# %%
m.save('C:/Users/Brown/Documents/my_map.html', title='My Map')

# %%
m.clear()

# %%
# Search in a GeoJSON 

countries = GeoJSON(data=data)

m = Map(center=[61.9389, 69.7851], zoom=2)

search = SearchControl(
    position="topleft",
    layer=LayerGroup(layers=(countries,)),
    property_name="Country",
)
m.add(search)
m
# Out:
# Map(bottom=456.0, center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
from ipywidgets import HTML
from ipyleaflet import Popup
from shapely.geometry import shape

def add_popup(feature, **kwargs):
    for layer in m.layers:
        if isinstance(layer, Popup):
            m.remove_layer(layer)
    p = shape(feature["geometry"])
    center = p.centroid.y, p.centroid.x
    properties = feature["properties"]
    message = HTML()
    message.value = f"""<h4>{properties["Country"]}</h4>
                        <b>Happiness Score: {properties["Happiness Score"]}
                     """
    popup = Popup(
        location=center,
        child=message,
        close_button=True,
        auto_close=False,
        close_on_escape_key=False,
    )

    m.add(popup)


search.on_feature_found(add_popup)
