# %%
# Dependencies and Setup
import pandas as pd
import requests
import numpy as np
import io
from pathlib import Path
from pprint import pprint
from ipyleaflet import Map, Marker
from geopy.exc import GeocoderTimedOut 
from geopy.geocoders import Nominatim

# %%
# Downloading the csv file from your GitHub account
# Make sure the url is the raw version of the file on GitHub
url = "https://raw.githubusercontent.com/brown016340/Project---3/benjamin/data/2015.csv"
download = requests.get(url).content

# Reading the downloaded content and turning it into a pandas dataframe
happy15_df = pd.read_csv(io.StringIO(download.decode('utf-8')))

# Printing out the first 5 rows of the dataframe
happy15_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
# Set Proper Name for Mali
condition = happy15_df['Country'] == 'Mali'
happy15_df.loc[condition, 'Country'] = 'Republic of Mali'

# %%
happy15_df['Country'].iloc[137]
# Out:
# 'Republic of Mali'

# %%
# Initialize Nominatim API
geolocator = Nominatim(user_agent="MyApp")

location = geolocator.geocode('Republic of mali')

print("The latitude of the location is: ", location.latitude)
print("The longitude of the location is: ", location.longitude)
# Out:
# The latitude of the location is:  16.3700359
# The longitude of the location is:  -2.2900239

# %%
lat = []
long = []

for index, row in happy15_df.iterrows():
    search = row['Country']
    print(f"Searching for {search}")
    location = geolocator.geocode(search, featuretype='country')
    lat.append(location.latitude)
    long.append(location.longitude)
    print(f"Coordinates found are: {location.latitude}, {location.longitude}")
# Out:
# Searching for Switzerland
# Coordinates found are: 46.7985624, 8.2319736
# Searching for Iceland
# Coordinates found are: 64.9841821, -18.1059013
# Searching for Denmark
# Coordinates found are: 55.670249, 10.3333283
# Searching for Norway
# Coordinates found are: 64.5731537, 11.52803643954819
# Searching for Canada
# Coordinates found are: 61.0666922, -107.991707
# Searching for Finland
# Coordinates found are: 63.2467777, 25.9209164
# Searching for Netherlands
# Coordinates found are: 52.2434979, 5.6343227
# Searching for Sweden
# Coordinates found are: 59.6749712, 14.5208584
# Searching for New Zealand
# Coordinates found are: -41.5000831, 172.8344077
# Searching for Australia
# Coordinates found are: -24.7761086, 134.755
# Searching for Israel
# Coordinates found are: 30.8124247, 34.8594762
# Searching for Costa Rica
# Coordinates found are: 9.536456900000001, -84.17566257468567
# Searching for Austria
# Coordinates found are: 36.9148511, -4.7534501
# Searching for Mexico
# Coordinates found are: 19.4326296, -99.1331785
# Searching for United States
# Coordinates found are: 39.7837304, -100.445882
# Searching for Brazil
# Coordinates found are: -10.3333333, -53.2
# Searching for Luxembourg
# Coordinates found are: 49.6112768, 6.129799
# Searching for Ireland
# Coordinates found are: 52.865196, -7.9794599
# Searching for Belgium
# Coordinates found are: 50.6402809, 4.6667145
# Searching for United Arab Emirates
# Coordinates found are: 24.0002488, 53.9994829
# Searching for United Kingdom
# Coordinates found are: 54.7023545, -3.2765753
# Searching for Oman
# Coordinates found are: 21.0000287, 57.0036901
# Searching for Venezuela
# Coordinates found are: 8.0018709, -66.1109318
# Searching for Singapore
# Coordinates found are: 1.357107, 103.8194992
# Searching for Panama
# Coordinates found are: 8.559559, -81.1308434
# Searching for Germany
# Coordinates found are: 40.4203479, -79.1166983
# Searching for Chile
# Coordinates found are: -31.7613365, -71.3187697
# Searching for Qatar
# Coordinates found are: 25.3336984, 51.2295295
# Searching for France
# Coordinates found are: 46.603354, 1.8883335
# Searching for Argentina
# Coordinates found are: -34.9964963, -64.9672817
# Searching for Czech Republic
# Coordinates found are: 49.7439047, 15.3381061
# Searching for Uruguay
# Coordinates found are: -32.8755548, -56.0201525
# Searching for Colombia
# Coordinates found are: 4.099917, -72.9088133
# Searching for Thailand
# Coordinates found are: 13.03876215, 101.70017611907599
# Searching for Saudi Arabia
# Coordinates found are: 25.6242618, 42.3528328
# Searching for Spain
# Coordinates found are: 39.3260685, -4.8379791
# Searching for Malta
# Coordinates found are: 35.8885993, 14.4476911
# Searching for Taiwan
# Coordinates found are: 23.5983227, 120.83537694479215
# Searching for Kuwait
# Coordinates found are: 29.3796532, 47.9734174
# Searching for Suriname
# Coordinates found are: 4.1413025, -56.0771187
# Searching for Trinidad and Tobago
# Coordinates found are: 10.7466905, -61.0840075
# Searching for El Salvador
# Coordinates found are: 13.8000382, -88.9140683
# Searching for Guatemala
# Coordinates found are: 15.5855545, -90.345759
# Searching for Uzbekistan
# Coordinates found are: 41.32373, 63.9528098
# Searching for Slovakia
# Coordinates found are: 48.7411522, 19.4528646
# Searching for Japan
# Coordinates found are: 36.5748441, 139.2394179
# Searching for South Korea
# Coordinates found are: 36.638392, 127.6961188
# Searching for Ecuador
# Coordinates found are: -1.3397668, -79.3666965
# Searching for Bahrain
# Coordinates found are: 25.227707549999998, 55.171549227823945
# Searching for Italy
# Coordinates found are: 42.6384261, 12.674297
# Searching for Bolivia
# Coordinates found are: -17.0568696, -64.9912286
# Searching for Moldova
# Coordinates found are: 47.2879608, 28.5670941
# Searching for Paraguay
# Coordinates found are: -23.3165935, -58.1693445
# Searching for Kazakhstan
# Coordinates found are: 48.1012954, 66.7780818
# Searching for Slovenia
# Coordinates found are: 46.1199444, 14.8153333
# Searching for Lithuania
# Coordinates found are: 55.3500003, 23.7499997
# Searching for Nicaragua
# Coordinates found are: 12.6090157, -85.2936911
# Searching for Peru
# Coordinates found are: -6.8699697, -75.0458515
# Searching for Belarus
# Coordinates found are: 53.4250605, 27.6971358
# Searching for Poland
# Coordinates found are: 52.215933, 19.134422
# Searching for Malaysia
# Coordinates found are: 4.5693754, 102.2656823
# Searching for Croatia
# Coordinates found are: 45.3658443, 15.6575209
# Searching for Libya
# Coordinates found are: 26.8234472, 18.1236723
# Searching for Russia
# Coordinates found are: 64.6863136, 97.7453061
# Searching for Jamaica
# Coordinates found are: 18.1850507, -77.3947693
# Searching for North Cyprus
# Coordinates found are: 35.2245313, 33.6252379
# Searching for Cyprus
# Coordinates found are: 34.9174159, 32.889902651331866
# Searching for Algeria
# Coordinates found are: 28.0000272, 2.9999825
# Searching for Kosovo
# Coordinates found are: 42.5869578, 20.9021231
# Searching for Turkmenistan
# Coordinates found are: 39.3763807, 59.3924609
# Searching for Mauritius
# Coordinates found are: -20.2759451, 57.5703566
# Searching for Hong Kong
# Coordinates found are: 22.350627, 114.1849161
# Searching for Estonia
# Coordinates found are: 58.7523778, 25.3319078
# Searching for Indonesia
# Coordinates found are: -2.4833826, 117.8902853
# Searching for Vietnam
# Coordinates found are: 15.9266657, 107.9650855
# Searching for Turkey
# Coordinates found are: 38.9597594, 34.9249653
# Searching for Kyrgyzstan
# Coordinates found are: 42.4858224, 74.714583
# Searching for Nigeria
# Coordinates found are: 9.6000359, 7.9999721
# Searching for Bhutan
# Coordinates found are: 27.549511, 90.5119273
# Searching for Azerbaijan
# Coordinates found are: 40.3936294, 47.7872508
# Searching for Pakistan
# Coordinates found are: 30.3308401, 71.247499
# Searching for Jordan
# Coordinates found are: 44.6663146, -93.6261918
# Searching for Montenegro
# Coordinates found are: -29.6826112, -51.4687455
# Searching for China
# Coordinates found are: 35.000074, 104.999927
# Searching for Zambia
# Coordinates found are: -14.5189121, 27.5589884
# Searching for Romania
# Coordinates found are: 45.9852129, 24.6859225
# Searching for Serbia
# Coordinates found are: 44.024322850000004, 21.07657433209902
# Searching for Portugal
# Coordinates found are: 39.6621648, -8.1353519
# Searching for Latvia
# Coordinates found are: 56.8406494, 24.7537645
# Searching for Philippines
# Coordinates found are: 12.7503486, 122.7312101
# Searching for Somaliland region
# Coordinates found are: 10.3743673, 45.1098578
# Searching for Morocco
# Coordinates found are: 28.3347722, -10.371337908392647
# Searching for Macedonia
# Coordinates found are: 41.1927739, -95.4256198
# Searching for Mozambique
# Coordinates found are: -19.302233, 34.9144977
# Searching for Albania
# Coordinates found are: 1.2315264, -75.89204331320687
# Searching for Bosnia and Herzegovina
# Coordinates found are: 44.3053476, 17.5961467
# Searching for Lesotho
# Coordinates found are: -29.6039267, 28.3350193
# Searching for Dominican Republic
# Coordinates found are: 19.0974031, -70.3028026
# Searching for Laos
# Coordinates found are: 20.0171109, 103.378253
# Searching for Mongolia
# Coordinates found are: 43.9382593, -79.2235563
# Searching for Swaziland
# Coordinates found are: -26.5624806, 31.3991317
# Searching for Greece
# Coordinates found are: 43.2097838, -77.6930602
# Searching for Lebanon
# Coordinates found are: 40.375713, -76.4626118
# Searching for Hungary
# Coordinates found are: 41.9767629, -72.7789842
# Searching for Honduras
# Coordinates found are: 15.2572432, -86.0755145
# Searching for Tajikistan
# Coordinates found are: 38.6281733, 70.8156541
# Searching for Tunisia
# Coordinates found are: 36.8002068, 10.1857757
# Searching for Palestinian Territories
# Coordinates found are: 31.762963620549996, 34.9384953773143
# Searching for Bangladesh
# Coordinates found are: -0.2864982, 36.0514231
# Searching for Iran
# Coordinates found are: 32.6475314, 54.5643516
# Searching for Ukraine
# Coordinates found are: 49.4871968, 31.2718321
# Searching for Iraq
# Coordinates found are: 33.0955793, 44.1749775
# Searching for South Africa
# Coordinates found are: -28.8166236, 24.991639
# Searching for Ghana
# Coordinates found are: 8.0300284, -1.0800271
# Searching for Zimbabwe
# Coordinates found are: -18.4554963, 29.7468414
# Searching for Liberia
# Coordinates found are: 5.7499721, -9.3658524
# Searching for India
# Coordinates found are: 22.3511148, 78.6677428
# Searching for Sudan
# Coordinates found are: 10.9, 6.5
# Searching for Haiti
# Coordinates found are: 19.1399952, -72.3570972
# Searching for Congo (Kinshasa)
# Coordinates found are: -2.9814344, 23.8222636
# Searching for Nepal
# Coordinates found are: 28.1083929, 84.0917139
# Searching for Ethiopia
# Coordinates found are: 6.7678, 35.6343712
# Searching for Sierra Leone
# Coordinates found are: 8.6400349, -11.8400269
# Searching for Mauritania
# Coordinates found are: -25.3669725, -54.3736391
# Searching for Kenya
# Coordinates found are: 1.4419683, 38.4313975
# Searching for Djibouti
# Coordinates found are: 11.8145966, 42.8453061
# Searching for Armenia
# Coordinates found are: 4.536307, -75.6723751
# Searching for Botswana
# Coordinates found are: -23.1681782, 24.5928742
# Searching for Myanmar
# Coordinates found are: 17.1750495, 95.9999652
# Searching for Georgia
# Coordinates found are: 32.3293809, -83.1137366
# Searching for Malawi
# Coordinates found are: -13.2687204, 33.9301963
# Searching for Sri Lanka
# Coordinates found are: 7.5554942, 80.7137847
# Searching for Cameroon
# Coordinates found are: 4.6125522, 13.1535811
# Searching for Bulgaria
# Coordinates found are: 46.7889169, 23.6184909
# Searching for Egypt
# Coordinates found are: 26.2540493, 29.2675469
# Searching for Yemen
# Coordinates found are: 16.3471243, 47.8915271
# Searching for Angola
# Coordinates found are: -11.8775768, 17.5691241
# Searching for Republic of Mali
# Coordinates found are: 16.3700359, -2.2900239
# Searching for Congo (Brazzaville)
# Coordinates found are: -0.7264327, 15.6419155
# Searching for Comoros
# Coordinates found are: -12.2045176, 44.2832964
# Searching for Uganda
# Coordinates found are: 1.5333554, 32.2166578
# Searching for Senegal
# Coordinates found are: 14.4750607, -14.4529612
# Searching for Gabon
# Coordinates found are: -0.8999695, 11.6899699
# Searching for Niger
# Coordinates found are: 17.7356214, 9.3238432
# Searching for Cambodia
# Coordinates found are: 4.0213151, -73.1292624
# Searching for Tanzania
# Coordinates found are: -6.5247123, 35.7878438
# Searching for Madagascar
# Coordinates found are: -18.9249604, 46.4416422
# Searching for Central African Republic
# Coordinates found are: 7.0323598, 19.9981227
# Searching for Chad
# Coordinates found are: 15.6134137, 19.0156172
# Searching for Guinea
# Coordinates found are: 10.7226226, -10.7083587
# Searching for Ivory Coast
# Coordinates found are: 7.9897371, -5.5679458
# Searching for Burkina Faso
# Coordinates found are: 12.0753083, -1.6880314
# Searching for Afghanistan
# Coordinates found are: 33.7680065, 66.2385139
# Searching for Rwanda
# Coordinates found are: -1.9646631, 30.0644358
# Searching for Benin
# Coordinates found are: 9.5293472, 2.2584408
# Searching for Syria
# Coordinates found are: 34.6401861, 39.0494106
# Searching for Burundi
# Coordinates found are: -3.426449, 29.9324519
# Searching for Togo
# Coordinates found are: 8.7800265, 1.0199765

# %%
# Same as above but uses a try except block to catch errors
geolocator = Nominatim(user_agent="your_app_name")

lat = []
long = []

for index, row in happy15_df.iterrows():
    search = row['Country']
    print(f"Searching for {search}")
    # Use try-except block to handle potential errors
    try:
        location = geolocator.geocode(search, featuretype='country')
        
        # Check if location is found before appending coordinates
        if location is not None:
            lat.append(location.latitude)
            long.append(location.longitude)
        else:
            lat.append(None)
            long.append(None)
        print(f"Coordinates found are: {location.latitude}, {location.longitude}")
    except Exception as e:
        print(f"Error for {search}: {e}")
        lat.append(None)
        long.append(None)
# Out:
# Searching for Switzerland
# Coordinates found are: 46.7985624, 8.2319736
# Searching for Iceland
# Coordinates found are: 64.9841821, -18.1059013
# Searching for Denmark
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# brown016340\Project---3\python\testing.ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2262656e6a616d696e227d7d/brown016340/Project---3/python/testing.ipynb#X30sdnNjb2RlLXZmcw%3D%3D?line=9'>10</a> # Use try-except block to handle potential errors
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2262656e6a616d696e227d7d/brown016340/Project---3/python/testing.ipynb#X30sdnNjb2RlLXZmcw%3D%3D?line=10'>11</a> try:
# ---> <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2262656e6a616d696e227d7d/brown016340/Project---3/python/testing.ipynb#X30sdnNjb2RlLXZmcw%3D%3D?line=11'>12</a>     location = geolocator.geocode(search)
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2262656e6a616d696e227d7d/brown016340/Project---3/python/testing.ipynb#X30sdnNjb2RlLXZmcw%3D%3D?line=13'>14</a>     # Check if location is found before appending coordinates
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a2262656e6a616d696e227d7d/brown016340/Project---3/python/testing.ipynb#X30sdnNjb2RlLXZmcw%3D%3D?line=14'>15</a>     if location is not None:
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\geopy\adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#     474         return resp.json()
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\geopy\adapters.py:482, in RequestsAdapter._request(self, url, timeout, headers)
#     480 def _request(self, url, *, timeout, headers):
#     481     try:
# --> 482         resp = self.session.get(url, timeout=timeout, headers=headers)
#     483     except Exception as error:
#     484         message = str(error)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\browba\AppData\Local\anaconda3\envs\dev\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(len(lat))
print(len(long))
# Out:
# 158
# 158

# %%
happy15_df['Latitude'] = lat
happy15_df['Longitude'] = long
happy15_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual   Latitude   Longitude
# 0     0.29678            2.51738  46.798562    8.231974
# 1     0.43630            2.70201  64.984182  -18.105901
# 2     0.34139            2.49204  55.670249   10.333328
# 3     0.34699            2.46531  64.573154   11.528036
# 4     0.45811            2.45176  61.066692 -107.991707

# %%
happy15_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
#  12  Latitude                       158 non-null    float64
#  13  Longitude                      158 non-null    float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 17.4+ KB

# %%
# plot all countries with a marker that shows name and happiness score
happy_map = Map(center=(0,0), zoom=1)

for index, row in happy15_df.iterrows():
    marker = Marker(location=[row.loc['Latitude'], row.loc['Longitude']],
                    title=row.loc['Country']+' Happiness Score: '+ str(row.loc['Happiness Score']))
    happy_map.add_layer(marker)

happy_map
# Out:
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…

# %%
# Same as above but uses a try except block to catch errors
geolocator = Nominatim(user_agent="your_app_name")

lat = []
long = []

search = 'Georgia'
location = geolocator.geocode(search, exactly_one=False,featuretype='country')
# print(f"Coordinates found are: {location.latitude}, {location.longitude}")
print(location)
# Out:
# [Location(South Georgia and the South Sandwich Islands, (-54.8432857, -35.8090698, 0.0)), Location(საქართველო, (41.6809707, 44.0287382, 0.0))]
